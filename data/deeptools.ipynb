# %%
import deeptools

# %%
# !computeMatrix scale-regions -S "/Users/sfurlan/Library/CloudStorage/OneDrive-SharedLibraries-FredHutchCancerCenter/Furlan_Lab_2025 - General/experiments/Leuklong/temp/NN_AML/all.fire.coverage.bw" -R ../hg38_gene_promoters_2kb_up_2kb_down.bed -o matrix.gz

# %%
# !plotHeatmap -m matrix.gz -o heatmap_m6a.png
# Out:
# /Users/sfurlan/micromamba/envs/deeptools/lib/python3.11/site-packages/deeptools/heatmapper.py:1219: RuntimeWarning:
#
# Mean of empty slice

# %%
# !computeMatrix scale-regions -S ../LL2_EW1.GRCh38.cpg_pileup.combined.bw -R ../hg38_gene_promoters_2kb_up_2kb_down.bed -o matrix_cpg.gz
# Out:
# Skipping ENSG00000056678.ENST00000417146, due to being absent in the computeMatrix output.
# Skipping ENSG00000096150.ENST00000481330, due to being absent in the computeMatrix output.
# Skipping ENSG00000096155.ENST00000483008, due to being absent in the computeMatrix output.
# Skipping ENSG00000096171.ENST00000489382, due to being absent in the computeMatrix output.
# Skipping ENSG00000111971.ENST00000464853, due to being absent in the computeMatrix output.
# Skipping ENSG00000112459.ENST00000230221, due to being absent in the computeMatrix output.
# Skipping ENSG00000112461.ENST00000400698, due to being absent in the computeMatrix output.
# Skipping ENSG00000112474.ENST00000480183, due to being absent in the computeMatrix output.
# Skipping ENSG00000112493.ENST00000467834, due to being absent in the computeMatrix output.
# Skipping ENSG00000137197.ENST00000259726, due to being absent in the computeMatrix output.
# ...

# %%
# !plotHeatmap -m matrix.gz -o heatmap_CpG.png
# Out:
# /Users/sfurlan/micromamba/envs/deeptools/lib/python3.11/site-packages/deeptools/heatmapper.py:1219: RuntimeWarning:
#
# Mean of empty slice

# %%
# !computeMatrix reference-point -S ../all.fire.coverage.bw -R ../hg38_gene_promoters_2kb_up_2kb_down.bed -o matrix_rp.gz
# Out:
# Skipping ENSG00000056678.ENST00000417146, due to being absent in the computeMatrix output.
# Skipping ENSG00000096150.ENST00000481330, due to being absent in the computeMatrix output.
# Skipping ENSG00000096155.ENST00000483008, due to being absent in the computeMatrix output.
# Skipping ENSG00000096171.ENST00000489382, due to being absent in the computeMatrix output.
# Skipping ENSG00000111971.ENST00000464853, due to being absent in the computeMatrix output.
# Skipping ENSG00000112459.ENST00000230221, due to being absent in the computeMatrix output.
# Skipping ENSG00000112461.ENST00000400698, due to being absent in the computeMatrix output.
# Skipping ENSG00000112474.ENST00000480183, due to being absent in the computeMatrix output.
# Skipping ENSG00000112493.ENST00000467834, due to being absent in the computeMatrix output.
# Skipping ENSG00000137197.ENST00000259726, due to being absent in the computeMatrix output.
# ...
